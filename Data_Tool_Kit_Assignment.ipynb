# %% [markdown]
# 1 - What is NumPy, and why is it widely used in Python?
# Ans - Numpy is a mathmatical library for computation, its greater performance and efficieny and wide varirty of function available.
#
# 2 - How does broadcasting work in NumPy?
#
# Ans - Broadcasting simplifies mathematical operations on arrays with different shapes. It enables NumPy to efficiently apply operations element-wise without explicitly copying or reshaping data.
#
# It automatically adjusts the smaller array to match the shape of the larger array by replicating its values along the necessary dimensions. This feature reduces memory usage and eliminates the need for manual loops making code concise and computationally faster making it essential for handling large datasets and performing complex calculations in python
#
# 3- What is a Pandas DataFrame?
# Ans - In Pandas, a DataFrame is a two-dimensional, size-mutable, and potentially heterogeneous tabular data structure. It's essentially a table with rows and columns, where each column can have a different data type (e.g., numbers, strings, booleans). DataFrames are incredibly versatile and are widely used for data analysis and manipulation in Python
#
# 4 - Explain the use of the groupby() method in Pandas?
# Ans - The groupby() method in Pandas split the data into groups based on the values in one or more columns. After grouping, you can then apply various aggregation functions, transformations, or filtering operations to each group independently.
#
# 5 - Why is Seaborn preferred for statistical visualizations?
#
# Ans - The power of Seaborn lies in its ability to seamlessly integrate with pandas. This integration allows users to visualize pandas DataFrames directly, making the transition from data analysis to data visualization incredibly smooth.
#
# 6 - What are the differences between NumPy arrays and Python lists?
#
# Ans - Numpy data type must be homegenous while Panda can support heterogeneous data type.
# Numpy are stored in contiguous memory locations	while panda can be scattered in memory locations
#
# Numpy is faster for numerical operations due to efficient memory access and optimized functions	while panda is slower for numerical operations due to type checking and general-purpose implementation.
#
# 7. What is a heatmap, and when should it be used ?
#
# ans - A heatmap is a data visualization tool that uses colors to represent values in a grid. Heatmaps are used to analyze large datasets and communicate relationships between data values
#
# 8 -  What does the term “vectorized operation” mean in NumPy?
#
# Ans - a vectorized operation refers to performing an operation on an entire array (or a portion of an array) at once, rather than iterating through individual elements using loops.
#
# 9 -  How does Matplotlib differ from Plotly?
#
# ans - Matplotlib is great for creating static visualizations, while Plotly is a more sophisticated tool that is better suited for creating elaborate plots more efficiently. Matplotlib is more explicit in declaring each plot element, making it an ideal place for new Python users to start, while Plotly is well-suited for creating interactive plots to be displayed in a web browser.
#
# 10 - What is the significance of hierarchical indexing in Pandas?
#
# Ans - It allows to have multiple levels of index labels on an axis (rows or columns) of a DataFrame. This enables to represent and manipulate data with complex structures and relationships.
#
# 11 - What is the role of Seaborn’s pairplot() function?
#
# Ans - The pairplot() function in Seaborn is used to create a grid of scatter plots that show the pairwise relationships between variables in a dataset.
#
# 12 - What is the purpose of the describe() function in Pandas?
#
# Ans - The describe () function return the statistical value of the dataframe or series.
#
# 13 - Why is handling missing data important in Pandas?
#
# Ans - Missing data, represented as NaN (Not a Number) values in Pandas, can significantly impact the accuracy and reliability of data analysis and modeling. If not handled properly, missing data can lead to biased results, incorrect inferences, and even errors in code.
#
# 14 What are the benefits of using Plotly for data visualization?
#
# Ans - Plotly offers a compelling combination of interactivity, web integration, customization, plot variety, collaboration features, and performance, making it a powerful and versatile tool for data visualization.
#
# 15 -  How does NumPy handle multidimensional arrays?
#
# Ans - Here's how NumPy handles multidimensional arrays:
#
#
# Data Representation,Shape and Dimensions,Indexing and Slicing,Broadcasting,Vectorized Operations,Reshaping and Transposing,Linear Algebra and Mathematical Functions.
#
# 16 - What is the role of Bokeh in data visualization?
#
# Ans - Roles of Bokeh in data visualization:
#
# Creating interactive plots: Bokeh allows you to create plots that can be interacted with by users. This means that users can zoom, pan, hover over data points, and select data points to get more information. This interactivity can make your visualizations more engaging and informative.
# Building web-based dashboards: Bokeh can be used to create web-based dashboards that allow users to explore data in an interactive way. This is a powerful way to share data insights with others, and it can be used to create custom data exploration tools for your team or organization.
# Visualizing large datasets: Bokeh is designed to handle large datasets efficiently. This means that you can use Bokeh to create visualizations of millions of data points without sacrificing performance. This makes Bokeh a good choice for visualizing data from big data applications.
# Streaming data visualization: Bokeh can be used to visualize streaming data, which is data that is constantly being updated. This is a useful feature for monitoring real-time data, such as stock prices or sensor readings.
# Customizable visualizations: Bokeh provides a wide range of customization options for your visualizations. This means that you can create plots that look exactly the way you want them to. You can also use Bokeh to create custom interactive elements for your plots, such as sliders and buttons.
#
# 17 Explain the difference between apply() and map() in Pandas ?
#
# Ans - map() is applied a function to each element of a Series.
# apply() is applied a function along an axis of a DataFrame or to each element of a Series.
#
# 18 -What are some advanced features of NumPy?
#
# Ans - Advanced features of Numpy are as below -
#
# a - Broadcasting, b - Avanced indexing, c - Memory Managment, d - Strustured Arrays,e - universal functions
# f - Linear Algebra, g - Fourier Transforms, h - Randon Number Generation, 9 - Interoperability, 10 C API
#
# 19 -  How does Pandas simplify time series analysis?
# Ans - It Simplifies the time series analysis as below -
#
# a - DateTimeIndex
# b - Resampling and Frequency Conversion
# c - time based indexing and slicing
# d- time zones
# e  -Date Offsets and Time Deltas:
# f - Window Functions
# g - Visualization
# h - Data Alignment and Merging
# i - Data Input/Output
#
# 20 -  What is the role of a pivot table in Pandas?
#
# The mainrle of pivot table in Panda is Data reshaping/aggrgation/exploration/visualization and reporting.
#
# 21 - Why is NumPy's array slicing faster than Python's list slicing ?
#
# Ans - NumPy's array slicing is faster than Python's list slicing due to efficient data storage, data type homogeneity, vectorized operations, and better cache utilization. These factors contribute to NumPy's overall performance advantage for numerical computations.
#
# 22- What are some common use cases for Seaborn?
# Ans - Seaborn provides a high-level interface for drawing attractive and informative statistical graphics

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

import plotly.graph_objects as go
import plotly.express as px

# %%
##1 - How do you create a 2D NumPy array and calculate the sum of each row?

arr = np.array([[1,2,3],[4,5,6]])
arr.ndim
row_sum = np.sum(arr, axis=1)
print(row_sum)
# Out:
# [ 6 15]

# %%
## A Write a Pandas script to find the mean of a specific column in a DataFrame?

## A Write a Pandas script to find the mean of a specific column in a DataFrame?

import pandas as pd
dt = pd.read_excel('Mrkt-PD1.xlsx')
dt1 = pd.DataFrame(dt)
dt1['Quantity'].mean()
# Out:
# 17743.48

# %%
##3-Create a scatter plot using Matplotlib ?

dt1.plot(x = 'Symbol' , y = 'Quantity', kind = 'scatter')
# Out:
# <Axes: xlabel='Symbol', ylabel='Quantity'>

# %%
 ## 4 - How do you calculate the correlation matrix using Seaborn and visualize it with a heatmap?

data = {"a":[1,2,3], "b": [4,5,6], "c": [6,7,8]}
df = pd.DataFrame(data)

cr_mtx = df.corr()

plt.figure(figsize=(8,6))
sns.heatmap(cr_mtx, annot=True, cmap='coolwarm', fmt ='.2f')
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
## 5 -Generate a bar plot using Plotly ?

fig = go.Figure()
fig.add

# %%
## 5 -Generate a bar plot using Plotly ?

fig = go.Figure()
fig.add_trace(go.Bar(x = [1,2,3,4], y = [4,5,6,7]))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
## 6 - Create a DataFrame and add a new column based on an existing column ?
## 6 - Create a DataFrame and add a new column based on an existing column ?
data = {"a":[1,2,3], "b": [4,5,6]}
df = pd.DataFrame(data)
df['b_g'] = pd.cut(df['b'], bins = [4,5,6,7], labels = ['q','w','e'])
print(df)
# Out:
#    a  b  b_g
# 0  1  4  NaN
# 1  2  5    q
# 2  3  6    w

# %%
## 7 - Write a program to perform element-wise multiplication of two NumPy arrays ?

l = [1,2,3,4]
l1 = [4,5,6,7]

arr = np.array(l)
arr1 = np.array(l1)
print(arr*arr1)
# Out:
# [ 4 10 18 28]

# %%
## 8 - A Create a line plot with multiple lines using Matplotlib?

x = np.random.rand(20)
y = np.random.rand(20)
plt.plot(x,y)

# %%
## 9. Generate a Pandas DataFrame and filter rows where a column value is greater than a threshold?

Data = pd.read_excel('Mrkt-PD1.xlsx')
df = pd.DataFrame(Data)
dt = df[df['Close'] > (df['Close'].mean())]
print(dt)
# Out:
#         Symbol    Close  Quantity          Cap      High      low  Sector  \
# 0          TCS  4200.00    117076  41274859.47   4592.25  3591.50      IT
# 3    NESTLEIND  2272.05      3355   8079841.69   2778.00  2145.40    FMCG
# 8    EICHERMOT  5150.00       378   7081817.58   5385.70  3562.45    AUTO
# 14  APOLLOHOSP  7090.00       219   7180583.28   7545.35  5693.20  HEALTH
# 16  BAJAJ-AUTO  8832.45       596   9780533.11  12774.00  6936.55    AUTO
# 19         M&M  3110.00      5082  27691258.25   3237.05  1575.00    AUTO
# 21  ASIANPAINT  2335.60      3107  10623705.47   3394.90  2256.50    FMCG
# 22       TITAN  3462.00       858  14416473.81   3886.95  3055.65    FMCG
# 23          LT  3499.95      6090  41561174.04   3963.50  3175.05  CONGLO
#
#      Size
# 0   Large
# 3     MID
# 8     MID
# 14  SMALL
# 16  SMALL
# 19  Large
# 21  Large
# 22  Large
# 23  Large

# %%
## 10  Create a histogram using Seaborn to visualize a distribution ?

Data = pd.read_excel('Mrkt-PD1.xlsx')
df = pd.DataFrame(Data)
dt = df[df['Close'] > (df['Close'].mean())]

sns.histplot(x = 'Symbol', y = 'Close', data = dt)
# Out:
# <Axes: xlabel='Symbol', ylabel='Close'>

# %%
## 11 -  Perform matrix multiplication using NumPy ?

mat = np.matrix([[1,2],[4,5]])
mat1 = np.matrix([[7,8],[9,4]])
mult = mat @ mat1
print(mult)
# Out:
# [[25 16]
#  [73 52]]

# %%
## 12 -  Use Pandas to load a CSV file and display its first 5 rows ?
df = pd.read_csv('Mrkt Data.csv')
print(df.head())
# Out:
#        Symbol  Pr_close     Close     Chg  %chg     Final Final qnty  \
# 0         TCS  4,038.85  4,200.00  161.15  3.99  4,200.00   1,17,076
# 1        INFY  1,917.30  1,937.00    19.7  1.03  1,937.00     32,348
# 2  SHRIRAMFIN  2,809.85       566    4.05  0.72       566      8,237
# 3   NESTLEIND  2,256.05  2,272.05      16  0.71  2,272.05      3,355
# 4       WIPRO     292.3     294.3       2  0.68     294.3     23,409
#
#         Val             Cap      High  ... Unnamed: 14  Unnamed: 15  \
# 0  4,917.19  4,12,74,859.47  4,592.25  ...         NaN          NaN
# 1    626.58  6,90,75,060.84  2,006.45  ...         NaN          NaN
# 2     46.62  3,94,86,975.28    730.45  ...         NaN          NaN
# 3     76.23    80,79,841.69  2,778.00  ...         NaN          NaN
# 4     68.89    82,74,238.74       320  ...         NaN          NaN
#
#    Unnamed: 16  Unnamed: 17  Unnamed: 18  Unnamed: 19  Unnamed: 20  \
# 0          NaN          NaN          NaN          NaN          NaN
# ...

# %%
 ## 13 - Create a 3D scatter plot using Plotly?

df = pd.read_csv('Mrkt Data.csv')
df1 = df.head()

fig = go.Figure()
fig.add_trace(go.Scatter3d(x=df1.Close, y=df1.Chg, z =df1.Cap))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
